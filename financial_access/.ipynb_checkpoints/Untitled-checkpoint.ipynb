# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Unbanked_and_underbanked_for_Nation__2017.csv")

# %%
df
# Out:
#                                  Type  percentage
# 0                            Unbanked         6.5
# 1                 Banked: Underbanked        18.7
# 2                Banked: Fully banked        68.4
# 3  Banked: Underbanked status unknown         6.3

# %%
plt.pie(df['percentage'],labels=df['Type'], radius=1.5, 
        autopct='%0.2f%%', textprops={'fontsize':14},shadow=True, explode=[.5,0,.5,.5])

plt.show()
